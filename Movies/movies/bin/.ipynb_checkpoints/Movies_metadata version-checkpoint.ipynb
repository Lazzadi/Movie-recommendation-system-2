# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ratings = pd.read_csv("/home/l/Documents/archive/ratings.csv")

# %%
movie_metadata = pd.read_csv("/home/l/Documents/archive/movies_metadata.csv", low_memory=False)
movie_metadata
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %%
movies_short = movie_metadata[['id','original_title','genres']]

# %%
movies_short['id'] = pd.to_numeric(movies_short['id'], errors='coerce')
# Out:
# /tmp/ipykernel_46661/3310365611.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_short['id'] = pd.to_numeric(movies_short['id'], errors='coerce')

# %%
movies_short['id'] = movies_short['id'].astype(float)
# Out:
# /tmp/ipykernel_46661/4055369743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_short['id'] = movies_short['id'].astype(float)

# %%
movies_short.dtypes
# Out:
# id                float64
# original_title     object
# genres             object
# dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2))

tfidf = vectorizer.fit_transform(movies_short['original_title'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

def search(original_title):
    query_vec = vectorizer.transform([original_title])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -5)[-5:]
    results = movies_short.iloc[indices][::-1]
    return results

# %%
import ipywidgets as widgets
from IPython.display import display

movie_input = widgets.Text(
    value="Toy Story",
    description="Movie Title:",
    disabled = False
)
movie_list = widgets.Output()

def on_type(data):
    with movie_list:
        movie_list.clear_output()
        original_title = data["new"]
        if len(original_title)>5:
            display(search(original_title))

movie_input.observe(on_type, names='value')

display(movie_input, movie_list)
# Out:
# Text(value='Toy Story', description='Movie Title:')
# Output()

# %%
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# ...          ...      ...     ...         ...
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
movie_id = 240

similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] >4)]["userId"].unique()

# %%
similar_users
# Out:
# array([  6906,   9622,  10382,  16707,  21375,  25639,  27679,  31760,
#         46102,  57927,  58795,  63535,  70726,  87361,  87760,  95600,
#        116193, 117194, 120022, 120400, 137168, 141499, 148185, 148739,
#        151222, 162396, 164336, 176841, 180658, 192823, 198037, 208158,
#        208730, 215627, 215731, 226508, 227188, 228933, 238074, 243015,
#        244002, 254659, 256012, 269775])

# %%
similar_users_recomendations = ratings[(ratings["userId"].isin(similar_users)) & (ratings["rating"] > 4)]["movieId"]

# %%
similar_users_recomendations
# Out:
# 678334         4
# 678337        17
# 678339        27
# 678340        31
# 678341        32
#             ...
# 25918582    5955
# 25918584    5991
# 25918585    5992
# 25918605    7158
# 25918606    7164
# Name: movieId, Length: 3669, dtype: int64

# %%
similar_users_recomendations = similar_users_recomendations.value_counts() / len(similar_users)

# %%
similar_users_recomendations = similar_users_recomendations[similar_users_recomendations > .1]

# %%
similar_users_recomendations
# Out:
# movieId
# 240     1.000000
# 318     0.477273
# 47      0.477273
# 593     0.477273
# 110     0.477273
#           ...
# 6       0.113636
# 348     0.113636
# 1259    0.113636
# 5       0.113636
# 248     0.113636
# Name: count, Length: 214, dtype: float64

# %%
all_users = ratings [(ratings["movieId"].isin(similar_users_recomendations.index)) & (ratings["rating"] > 4)]

# %%
all_users #all users who watched our movie
# Out:
#           userId  movieId  rating   timestamp
# 2              1      858     5.0  1425941523
# 6              1     2762     4.5  1425941300
# 35             2      339     5.0   867041296
# 89             4     2762     5.0  1042672546
# 124            5      541     5.0   949424321
# ...          ...      ...     ...         ...
# 26024085  270896      858     5.0  1257031915
# 26024097  270896     1193     5.0  1257033874
# 26024098  270896     1200     4.5  1257031892
# 26024101  270896     1214     5.0  1257031943
# 26024163  270896     2762     5.0  1257031486
#
# [1238021 rows x 4 columns]

# %%
all_users_recomendations = all_users["movieId"].value_counts() /len(all_users["userId"].unique())

# %%
all_users_recomendations
# Out:
# movieId
# 318    0.312044
# 296    0.248673
# 356    0.214068
# 593    0.205899
# 260    0.201955
#          ...
# 132    0.000491
# 606    0.000395
# 416    0.000368
# 240    0.000235
# 472    0.000160
# Name: count, Length: 214, dtype: float64

# %%
recomendation_percentages = pd.concat([similar_users_recomendations, all_users_recomendations], axis = 1)

# %%
recomendation_percentages.columns = ["similar", "all"]

# %%
recomendation_percentages
# Out:
#           similar       all
# movieId
# 240      1.000000  0.000235
# 318      0.477273  0.312044
# 47       0.477273  0.119171
# 593      0.477273  0.205899
# 110      0.477273  0.147426
# ...           ...       ...
# 6        0.113636  0.043500
# 348      0.113636  0.009077
# 1259     0.113636  0.041397
# 5        0.113636  0.006916
# 248      0.113636  0.001057
#
# [214 rows x 2 columns]

# %%
recomendation_percentages["score"] = recomendation_percentages["similar"] / recomendation_percentages["all"]

# %%
recomendation_percentages
# Out:
#           similar       all        score
# movieId
# 240      1.000000  0.000235  4259.159091
# 318      0.477273  0.312044     1.529504
# 47       0.477273  0.119171     4.004941
# 593      0.477273  0.205899     2.318000
# 110      0.477273  0.147426     3.237380
# ...           ...       ...          ...
# 6        0.113636  0.043500     2.612340
# 348      0.113636  0.009077    12.519574
# 1259     0.113636  0.041397     2.745011
# 5        0.113636  0.006916    16.431941
# 248      0.113636  0.001057   107.554522
#
# [214 rows x 3 columns]

# %%
recomendation_percentages = recomendation_percentages.sort_values("score", ascending = False)

# %%
recomendation_percentages.head(20).merge(movies_short, left_on = "movieId", right_on = "id")
# Out:
#      similar       all        score     id  \
# 0   1.000000  0.000235  4259.159091  240.0
# 1   0.159091  0.000491   324.066453  132.0
# 2   0.113636  0.000395   287.781020  606.0
# 3   0.181818  0.000779   233.378580  177.0
# 4   0.113636  0.000518   219.544283  174.0
# 5   0.136364  0.000683   199.648082   92.0
# 6   0.113636  0.000576   197.183291  332.0
# 7   0.159091  0.000811   196.145484  271.0
# 8   0.159091  0.000854   186.338210  219.0
# 9   0.181818  0.001201   151.436768  426.0
# 10  0.113636  0.000784   144.869357  103.0
# 11  0.136364  0.000998   136.657511  234.0
# 12  0.204545  0.001526   134.029482  490.0
# 13  0.136364  0.001041   131.051049  640.0
# 14  0.204545  0.001563   130.827412  338.0
#
#                             original_title  \
# 0                   The Godfather: Part II
# 1        The Rolling Stones: Gimme Shelter
# 2                            Out of Africa
# 3                          The Fisher King
# 4   Star Trek VI: The Undiscovered Country
# 5                               Megacities
# 6                         Inspector Gadget
# 7                        Ronja Rövardotter
# 8                                   Volver
# 9                                  Vertigo
# 10                             Taxi Driver
# 11            Das Cabinet des Dr. Caligari
# 12                     Det sjunde inseglet
# 13                     Catch Me If You Can
# 14                        Good bye, Lenin!
#
#                                                genres
# 0   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 1   [{'id': 99, 'name': 'Documentary'}, {'id': 104...
# 2                       [{'id': 18, 'name': 'Drama'}]
# 3   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 5                 [{'id': 99, 'name': 'Documentary'}]
# 6   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 7   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 8   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 9   [{'id': 9648, 'name': 'Mystery'}, {'id': 10749...
# 10  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 11  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 13  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 14  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
